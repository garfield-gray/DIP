# %% [markdown]
# <a href="https://colab.research.google.com/github/garfield-gray/DIP/blob/main/dipHW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#4/14/2023, Let's begin
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #First Problem

# %%
# first off we upload the image
im = plt.imread("1.png", ".png")

# %%
plt.figure(figsize = (4,7))
plt.imshow(im, cmap="gray")
plt.show()

# %%
im.shape
# Out:
# (320, 240)

# %%
# transformaton to signal domain through fft
imf = np.fft.fft2(im)
plt.figure(figsize = (4,7))
plt.imshow((imf.real/np.max(imf.real)), cmap="gray")
plt.show()

# %%
im[100:110,200:202].real/np.max(im[100:110,200:202].real)
# Out:
# array([[0.465, 0.46 ],
#        [0.545, 0.55 ],
#        [0.855, 0.855],
#        [1.   , 0.99 ],
#        [0.875, 0.87 ],
#        [0.57 , 0.565],
#        [0.43 , 0.435],
#        [0.73 , 0.725],
#        [0.96 , 0.97 ],
#        [0.955, 0.97 ]], dtype=float32)

# %%
(imf.real/np.max(imf.real)).shape
# Out:
# (320, 240)

# %%
imf.shape
# Out:
# (320, 240)

# %%
im.shape
# Out:
# (320, 240)

# %%
plt.figure(figsize = (4,7))
plt.imshow((imf.real/np.max(imf.real))[1:320,1:240], cmap="gray")
plt.show()

# %%
(imf.real/np.max(imf.real))[100:102,100:102]
# Out:
# array([[ 4.66261687e-06, -1.39916177e-05],
#        [ 1.60032938e-05,  9.27172804e-06]])
