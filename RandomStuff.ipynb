# %% [markdown]
# <a href="https://colab.research.google.com/github/garfield-gray/DIP/blob/main/RandomStuff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
image1 = cv2.imread('gdrive/MyDrive/Uni/DIP/unnamed.jpg')
from google.colab.patches import cv2_imshow
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=288x288>

# %%
gray = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
invert = cv2.bitwise_not(gray)
cv2_imshow(invert)
# Out:
# <PIL.Image.Image image mode=L size=288x288>
# <PIL.Image.Image image mode=L size=288x288>

# %%
blur = cv2.GaussianBlur(invert, (21, 21), 0)
cv2_imshow(blur)
invertedblur = cv2.bitwise_not(blur)
cv2_imshow(invertedblur)
sketch = cv2.divide(gray, invertedblur, scale =256.0)
cv2_imshow(sketch)
cv2.imwrite("sketch.jpg", sketch)
# Out:
# <PIL.Image.Image image mode=L size=288x288>
# <PIL.Image.Image image mode=L size=288x288>
# <PIL.Image.Image image mode=L size=288x288>
# True
